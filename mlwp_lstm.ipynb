# %%
import pandas as pd

# %%
df = pd.read_csv('reddit.csv')

# %%
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0          read first think someone know narcissist!
# 1             1  biweekly ask narcissist thread visitors/codepe...
# 2             2                                relationship advice
# 3             3    leave someone might covert narcissistic traits?
# 4             4                                      trust change?
# ..          ...                                                ...
# 595         595                          hi, new really sure start
# 596         596                                bpd autism comorbid
# 597         597                                        get rid fp?
# 598         598               people try tell you’re misdiagnosed?
# 599         599                                      might delete…
#
#                                                   text  \
# 0    narcissists people think narcissists allowed p...
# 1    thread ask questions narcissists, know cluster...
# 2    i’m getting really annoyed people here; think ...
# 3    leave someone might covert narcissistic traits...
# 4    husband showed strong narcissistic traits past...
# ..                                                 ...
# 595  i’ve really painful relationship long time, i’...
# 596  anybody diagnosed good idea look like together...
# 597  context, won’t say age, think fp one online fr...
# 598  i’ve people start telling either got misdiagno...
# 599  hi guys first post… hate bpd, time feel like s...
#
#                                          combined_text   subreddit  label
# 0    read first think someone know narcissist! narc...  narcissism      1
# 1    biweekly ask narcissist thread visitorscodepen...  narcissism      1
# 2    relationship advice im getting really annoyed ...  narcissism      1
# 3    leave someone might covert narcissistic traits...  narcissism      1
# 4    trust change? husband showed strong narcissist...  narcissism      1
# ..                                                 ...         ...    ...
# 595  hi, new really sure start ive really painful r...         bpd      0
# 596  bpd autism comorbid anybody diagnosed good ide...         bpd      0
# 597  get rid fp? context, wont say age, think fp on...         bpd      0
# 598  people try tell youre misdiagnosed? ive people...         bpd      0
# 599  might delete hi guys first post hate bpd, time...         bpd      0
#
# [600 rows x 6 columns]

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#                                                  title  \
# 0            read first think someone know narcissist!
# 1    biweekly ask narcissist thread visitors/codepe...
# 2                                  relationship advice
# 3      leave someone might covert narcissistic traits?
# 4                                        trust change?
# ..                                                 ...
# 595                          hi, new really sure start
# 596                                bpd autism comorbid
# 597                                        get rid fp?
# 598               people try tell you’re misdiagnosed?
# 599                                      might delete…
#
#                                                   text  \
# 0    narcissists people think narcissists allowed p...
# 1    thread ask questions narcissists, know cluster...
# 2    i’m getting really annoyed people here; think ...
# 3    leave someone might covert narcissistic traits...
# 4    husband showed strong narcissistic traits past...
# ..                                                 ...
# 595  i’ve really painful relationship long time, i’...
# 596  anybody diagnosed good idea look like together...
# 597  context, won’t say age, think fp one online fr...
# 598  i’ve people start telling either got misdiagno...
# 599  hi guys first post… hate bpd, time feel like s...
#
#                                          combined_text   subreddit  label
# 0    read first think someone know narcissist! narc...  narcissism      1
# 1    biweekly ask narcissist thread visitorscodepen...  narcissism      1
# 2    relationship advice im getting really annoyed ...  narcissism      1
# 3    leave someone might covert narcissistic traits...  narcissism      1
# 4    trust change? husband showed strong narcissist...  narcissism      1
# ..                                                 ...         ...    ...
# 595  hi, new really sure start ive really painful r...         bpd      0
# 596  bpd autism comorbid anybody diagnosed good ide...         bpd      0
# 597  get rid fp? context, wont say age, think fp on...         bpd      0
# 598  people try tell youre misdiagnosed? ive people...         bpd      0
# 599  might delete hi guys first post hate bpd, time...         bpd      0
#
# [600 rows x 5 columns]

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
import random
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
X = df['combined_text']
y = df['label']

# %%
from tensorflow.keras.layers import TextVectorization as TV

# %%
vocab_size = 5000
tv = TV(max_tokens = 5000, output_mode = 'int')

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state = 42, test_size = 0.2, stratify = y)

# %%
tv.adapt(X_train)

# %%
print(len(tv.get_vocabulary()))
# Out:
# 5000

# %%
X_train_seq = tv(tf.constant(X_train))
X_val_seq = tv(tf.constant(X_val))

# %%
def lstm_model(embedding_dim, lstm_units, dropout_rate, learning_rate):
  model = keras.Sequential([
      layers.Embedding(vocab_size, embedding_dim),
      layers.Bidirectional(LSTM(units=lstm_units, return_sequences=True)),
      layers.Dropout(dropout_rate),
      layers.Bidirectional(LSTM(units=lstm_units // 2)),
      layers.Dropout(rate=dropout_rate),
      layers.Dense(1, activation = 'sigmoid')
  ])

  model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
  return model

# %%
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score
from sklearn.utils.class_weight import compute_class_weight
embedding_dims = [64, 128]
lstm_units_list = [32, 64]
dropout_rates = [0.3, 0.5]
learning_rates = [1e-3, 5e-4]
epochs = 5
batch_size = 32

best_f1 = 0
best_scores = {}
best_config = {}
best_model = None

class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(enumerate(class_weights))

my_callbacks = [
    keras.callbacks.EarlyStopping(
        monitor = 'val_accuracy',
        patience = 3),
    keras.callbacks.ModelCheckpoint(
        filepath = 'best_model.keras',
        monitor = 'val_accuracy',
        save_best_only = True,
        verbose = 1)
]

for emb in embedding_dims:
  for unit in lstm_units_list:
    for dropout in dropout_rates:
      for learn in learning_rates:
        print(f"\n Trying emb={emb}, lstm={unit}, drop={dropout}, lr={learn}")
        model = lstm_model(emb, unit, dropout, learn)
        history = model.fit(
            x = X_train_seq,
            y = y_train,
            batch_size = 32,
            epochs = 100,
            class_weight=class_weights,
            validation_data = (X_val_seq, y_val),
            callbacks = my_callbacks)

        y_pred = (model.predict(X_val_seq) > 0.3).astype("int32")
        f1 = f1_score(y_val, y_pred)
        acc = accuracy_score(y_val, y_pred)
        prec = precision_score(y_val, y_pred)
        rec = recall_score(y_val, y_pred)


        print(f"F1 Score: {f1:.4f}")

        if f1 > best_f1:
           best_f1 = f1
           best_config = {
               'embedding_dim': emb,
               'lstm_units': unit,
               'dropout_rate': dropout,
               'learning_rate': learn
           }
           best_model = model
           best_scores = {
            'f1': f1,
            'accuracy': acc,
            'precision': prec,
            'recall': rec
            }
# Out:
#  Trying emb=64, lstm=32, drop=0.3, lr=0.001
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5553 - loss: 0.6846
# Epoch 1: val_accuracy improved from -inf to 0.83333, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.5595 - loss: 0.6849 - val_accuracy: 0.8333 - val_loss: 0.6778
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - accuracy: 0.7904 - loss: 0.6555
# Epoch 2: val_accuracy improved from 0.83333 to 0.85000, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7904 - loss: 0.6548 - val_accuracy: 0.8500 - val_loss: 0.5785
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 896ms/step - accuracy: 0.8831 - loss: 0.5063
# Epoch 3: val_accuracy improved from 0.85000 to 0.87500, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 996ms/step - accuracy: 0.8837 - loss: 0.5018 - val_accuracy: 0.8750 - val_loss: 0.4045
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 886ms/step - accuracy: 0.9198 - loss: 0.3147
# Epoch 4: val_accuracy improved from 0.87500 to 0.88333, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 984ms/step - accuracy: 0.9203 - loss: 0.3136 - val_accuracy: 0.8833 - val_loss: 0.3304
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 897ms/step - accuracy: 0.9763 - loss: 0.1843
# Epoch 5: val_accuracy did not improve from 0.88333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 991ms/step - accuracy: 0.9762 - loss: 0.1836 - val_accuracy: 0.8750 - val_loss: 0.3911
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 882ms/step - accuracy: 0.9628 - loss: 0.1697
# Epoch 6: val_accuracy improved from 0.88333 to 0.89167, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 943ms/step - accuracy: 0.9628 - loss: 0.1693 - val_accuracy: 0.8917 - val_loss: 0.2748
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 890ms/step - accuracy: 0.9994 - loss: 0.0443
# Epoch 7: val_accuracy did not improve from 0.89167
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 983ms/step - accuracy: 0.9993 - loss: 0.0442 - val_accuracy: 0.8750 - val_loss: 0.4105
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 906ms/step - accuracy: 0.9893 - loss: 0.0373
# Epoch 8: val_accuracy improved from 0.89167 to 0.90833, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 967ms/step - accuracy: 0.9895 - loss: 0.0370 - val_accuracy: 0.9083 - val_loss: 0.2823
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 877ms/step - accuracy: 1.0000 - loss: 0.0154
# Epoch 9: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 971ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.9000 - val_loss: 0.3096
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 884ms/step - accuracy: 0.9992 - loss: 0.0125
# Epoch 10: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 977ms/step - accuracy: 0.9991 - loss: 0.0126 - val_accuracy: 0.8833 - val_loss: 0.3400
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 877ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 11: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 933ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9083 - val_loss: 0.2717
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 387ms/step
# F1 Score: 0.8706
#
#  Trying emb=64, lstm=32, drop=0.3, lr=0.0005
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.5528 - loss: 0.6864
# Epoch 1: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.5582 - loss: 0.6867 - val_accuracy: 0.8833 - val_loss: 0.6810
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.8882 - loss: 0.6589
# Epoch 2: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 930ms/step - accuracy: 0.8885 - loss: 0.6582 - val_accuracy: 0.9083 - val_loss: 0.6109
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 881ms/step - accuracy: 0.9065 - loss: 0.5187
# Epoch 3: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 975ms/step - accuracy: 0.9067 - loss: 0.5147 - val_accuracy: 0.8917 - val_loss: 0.4058
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.9643 - loss: 0.2568
# Epoch 4: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 956ms/step - accuracy: 0.9639 - loss: 0.2554 - val_accuracy: 0.8750 - val_loss: 0.3132
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 881ms/step - accuracy: 0.9951 - loss: 0.1337
# Epoch 5: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 936ms/step - accuracy: 0.9949 - loss: 0.1328 - val_accuracy: 0.8667 - val_loss: 0.3427
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 381ms/step
# F1 Score: 0.8235
#
#  Trying emb=64, lstm=32, drop=0.5, lr=0.001
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 851ms/step - accuracy: 0.6975 - loss: 0.6828
# Epoch 1: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 966ms/step - accuracy: 0.6968 - loss: 0.6831 - val_accuracy: 0.8083 - val_loss: 0.6753
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - accuracy: 0.7575 - loss: 0.6524
# Epoch 2: val_accuracy did not improve from 0.90833
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9566 - loss: 0.2896
# Epoch 3: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9568 - loss: 0.2864 - val_accuracy: 0.9000 - val_loss: 0.3028
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9969 - loss: 0.0701
# Epoch 4: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9967 - loss: 0.0698 - val_accuracy: 0.8750 - val_loss: 0.4955
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0472
# Epoch 5: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9919 - loss: 0.0485 - val_accuracy: 0.8667 - val_loss: 0.5703
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9981 - loss: 0.0229
# Epoch 6: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9980 - loss: 0.0238 - val_accuracy: 0.8667 - val_loss: 0.5953
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step
# F1 Score: 0.7949
#
#  Trying emb=128, lstm=64, drop=0.5, lr=0.001
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5022 - loss: 0.6851
# Epoch 1: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.5080 - loss: 0.6853 - val_accuracy: 0.8500 - val_loss: 0.6714
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7997 - loss: 0.6301
# Epoch 2: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.7996 - loss: 0.6281 - val_accuracy: 0.8500 - val_loss: 0.4510
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9482 - loss: 0.3417
# Epoch 3: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9477 - loss: 0.3380 - val_accuracy: 0.8833 - val_loss: 0.2838
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9764 - loss: 0.1232
# Epoch 4: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9767 - loss: 0.1223 - val_accuracy: 0.8917 - val_loss: 0.3512
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9947 - loss: 0.0515
# Epoch 5: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9946 - loss: 0.0514 - val_accuracy: 0.8583 - val_loss: 0.6072
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9954 - loss: 0.0269
# Epoch 6: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9951 - loss: 0.0281 - val_accuracy: 0.8667 - val_loss: 0.6528
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9987 - loss: 0.0167
# Epoch 7: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9987 - loss: 0.0170 - val_accuracy: 0.8583 - val_loss: 0.7105
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 533ms/step
# F1 Score: 0.7901
#
#  Trying emb=128, lstm=64, drop=0.5, lr=0.0005
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5769 - loss: 0.6848
# Epoch 1: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.5776 - loss: 0.6850 - val_accuracy: 0.3750 - val_loss: 0.6840
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6911 - loss: 0.6119
# Epoch 2: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.6961 - loss: 0.6086 - val_accuracy: 0.8500 - val_loss: 0.4517
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9282 - loss: 0.3409
# Epoch 3: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9288 - loss: 0.3375 - val_accuracy: 0.8750 - val_loss: 0.3435
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9798 - loss: 0.1264
# Epoch 4: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9799 - loss: 0.1255 - val_accuracy: 0.8667 - val_loss: 0.4857
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9888 - loss: 0.0624
# Epoch 5: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9885 - loss: 0.0631 - val_accuracy: 0.8417 - val_loss: 0.6525
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9843 - loss: 0.0967
# Epoch 6: val_accuracy did not improve from 0.93333
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9845 - loss: 0.0957 - val_accuracy: 0.8583 - val_loss: 0.5171
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 551ms/step
# F1 Score: 0.8193

# %%
best_model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)        │ (32, 702, 128)         │       640,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_20                │ (32, 702, 64)          │        41,216 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (32, 702, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_21                │ (32, 32)               │        10,368 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (32, 32)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (32, 1)                │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,074,853 (7.91 MB)
#  Trainable params: 691,617 (2.64 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,383,236 (5.28 MB)

# %%
print("Best LSTM Configuration:")
for k, v in best_config.items():
    print(f"{k}: {v}")
print(f"Best F1 Score on Validation Set: {best_f1:.4f}")
print("Metrics for Best Model:")
for k, v in best_scores.items():
    print(f"{k.capitalize():<9}: {v:.4f}")
# Out:
# Best LSTM Configuration:
# embedding_dim: 128
# lstm_units: 32
# dropout_rate: 0.3
# learning_rate: 0.0005
# Best F1 Score on Validation Set: 0.8780
# Metrics for Best Model:
# F1       : 0.8780
# Accuracy : 0.9167
# Precision: 0.8571
# Recall   : 0.9000
